# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import zipfile
import os
import seaborn as sns
sns.set(style="whitegrid")
import numpy as np
import scipy.stats as stats

# optional for text EDA
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
os.getcwd()
# Out:
# 'C:\\Users\\l\\moringa\\Phase2\\Phase2_project\\dsc-phase-2-project-G3'

# %%
bmovie_gross = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
bmovie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
tmdb_movies = pd.read_csv('zippedData/tmdb.movies.csv.gz')
tmdb_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
tnmovie_budgets = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
tnmovie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
rt_movie = pd.read_csv("zippedData/rt.movie_info.tsv.gz", sep="\t", header=None, encoding="utf-8")
rt_movie.head()
# Out:
#    0                                                  1       2   \
# 0  id                                           synopsis  rating
# 1   1  This gritty, fast-paced, and innovative police...       R
# 2   3  New York City, not-too-distant-future: Eric Pa...       R
# 3   5  Illeana Douglas delivers a superb performance ...       R
# 4   6  Michael Douglas runs afoul of a treacherous su...       R
#
#                                     3                 4   \
# 0                                genre          director
# 1  Action and Adventure|Classics|Drama  William Friedkin
# 2    Drama|Science Fiction and Fantasy  David Cronenberg
# 3    Drama|Musical and Performing Arts    Allison Anders
# 4           Drama|Mystery and Suspense    Barry Levinson
#
#                                 5             6             7         8   \
# 0                           writer  theater_date      dvd_date  currency
# 1                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001       NaN
# ...

# %%
rt_reviews = pd.read_csv("zippedData/rt.reviews.tsv.gz", sep="\t", header=None, encoding = 'latin1')
rt_reviews.head()
# Out:
#     0                                                  1       2       3  \
# 0  id                                             review  rating   fresh
# 1   3  A distinctly gallows take on contemporary fina...     3/5   fresh
# 2   3  It's an allegory in search of a meaning that n...     NaN  rotten
# 3   3  ... life lived in a bubble in financial dealin...     NaN   fresh
# 4   3  Continuing along a line introduced in last yea...     NaN   fresh
#
#                 4           5                 6                  7
# 0          critic  top_critic         publisher               date
# 1      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 2  Annalee Newitz           0           io9.com       May 23, 2018
# 3    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 4   Daniel Kasman           0              MUBI  November 16, 2017

# %%
#shape of data
rt_reviews.shape
# Out:
# (54433, 8)

# %%
#columns in rt_reviews
print(rt_reviews.columns)
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6, 7], dtype='int64')

# %%
#data types in each column
print(rt_reviews.dtypes)
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# 7    object
# dtype: object

# %%
#data summary
print(rt_reviews.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54433 entries, 0 to 54432
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       54433 non-null  object
#  1   1       48870 non-null  object
#  2   2       40916 non-null  object
#  3   3       54433 non-null  object
#  4   4       51711 non-null  object
#  5   5       54433 non-null  object
#  6   6       54124 non-null  object
#  7   7       54433 non-null  object
# dtypes: object(8)
# memory usage: 3.3+ MB
# None

# %%
#naming of columns
rt_reviews.columns = [f"col_{i}" for i in range(rt_reviews.shape[1])]
rt_reviews.columns
# Out:
# Index(['col_0', 'col_1', 'col_2', 'col_3', 'col_4', 'col_5', 'col_6', 'col_7'], dtype='object')

# %%
#to remove white spaces
str_cols = rt_reviews.select_dtypes(include="object").columns
rt_reviews[str_cols] = rt_reviews[str_cols].apply(lambda s: s.str.strip())

# %%
#show missing values
missing = rt_reviews.isna().sum().sort_values(ascending=False)
display(missing[missing > 0])
# Out:
# col_2    13517
# col_1     5563
# col_4     2722
# col_6      309
# dtype: int64

# %%
#to find unique value counts
for col in rt_reviews.columns:
    n = rt_reviews[col].nunique(dropna=False)
    print(col, "unique:", n)
# Out:
# col_0 unique: 1136
# col_1 unique: 48683
# col_2 unique: 188
# col_3 unique: 2
# col_4 unique: 3498
# col_5 unique: 3
# col_6 unique: 1283
# col_7 unique: 5964

# %%
#to fix numeric columns stored as text
for col in rt_reviews.columns:
    rt_reviews[col] = pd.to_numeric(rt_reviews[col], errors="coerce")

# %%
# Select numeric columns
num_cols = rt_reviews.select_dtypes(include=[np.number]).columns.tolist()

# Summary stats for numeric columns
print(rt_reviews[num_cols].describe().T)

# Histograms for each numeric column
for c in num_cols:
    plt.figure(figsize=(6, 3))
    sns.histplot(rt_reviews[c].dropna(), kde=False)  # use rt_reviews, not df
    plt.title(c)
    plt.show()
# Out:
#          count         mean         std  min    25%     50%       75%     max
# col_0  54432.0  1045.706882  586.657046  3.0  542.0  1083.0  1541.000  2000.0
# col_1      0.0          NaN         NaN  NaN    NaN     NaN       NaN     NaN
# col_2    750.0     5.135733    2.716021  0.0    3.0     6.0     7.775     9.8
# col_3      0.0          NaN         NaN  NaN    NaN     NaN       NaN     NaN
# col_4      0.0          NaN         NaN  NaN    NaN     NaN       NaN     NaN
# col_5  54432.0     0.240594    0.427448  0.0    0.0     0.0     0.000     1.0
# col_6      0.0          NaN         NaN  NaN    NaN     NaN       NaN     NaN
# col_7      0.0          NaN         NaN  NaN    NaN     NaN       NaN     NaN

# %%
#find skew, common categories, imbalanced labels.
cat_cols = rt_reviews.select_dtypes(include=["category","object"]).columns.tolist()
for c in cat_cols:
    print("----", c)
    display(rt_reviews[c].value_counts().head(20))

# %%
# correlations for numeric features(finds predictors and confirms expected relationship)
if len(num_cols) >= 2:
    plt.figure(figsize=(6,5))
    sns.heatmap(rt_reviews[num_cols].corr(), annot=True, fmt=".2f", cmap="vlag")
    plt.title("Correlation matrix")
    plt.show()

# %%
#checkout for duplicates in all columns
for col in rt_reviews.select_dtypes(include="object").columns:
    print(col, ":", rt_reviews.duplicated(subset=[col]).sum())
