# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Import all the relevant libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import sqlite3
import zipfile
import os

# %%
import os
os.listdir()
# Out:
# ['temp_folder',
#  'LICENSE.md',
#  'Temp Folder',
#  '.DS_Store',
#  'tmdb.movies.csv.gz',
#  'tmdb.movies.csv',
#  'student.ipynb',
#  'rt.reviews.tsv',
#  'movie_data_erd.jpeg',
#  'tn.movie_budgets.csv',
#  'README.md',
#  '.gitignore',
#  'CONTRIBUTING.md',
#  'bom.movie_gross.csv',
#  'rt.movie_info.tsv',
#  'rt.reviews.tsv.gz',
#  '.ipynb_checkpoints',
#  '.git',
#  'rt.movie_info.tsv.gz',
#  'zippedData',
#  'index.ipynb',
#  'tn.movie_budgets.csv.gz',
#  'bom.movie_gross.csv.gz']

# %%
import os 
os.getcwd()
# Out:
# '/Users/fatuma/Documents/PHASE 2 MORINGA/dsc-phase-2-project-G3'

# %%
from pathlib import Path
import sqlite3, pandas as pd

db = Path("temp_folder/im.db")          # launch Jupyter from the repo root so this path works
assert db.exists() and db.stat().st_size > 0

with sqlite3.connect(str(db)) as conn:
    print(pd.read_sql_query(
        "SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%' ORDER BY name;",
        conn
    ))
# Out:
#             name
# 0      directors
# 1      known_for
# 2     movie_akas
# 3   movie_basics
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers
